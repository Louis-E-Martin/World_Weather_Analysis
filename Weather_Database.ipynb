# %%
# Import the dependencies.
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
# Import linregress
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description" : weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | kula
# Processing Record 5 of Set 1 | avera
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ca mau
# Processing Record 14 of Set 1 | mount hagen
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | calama
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | imbituba
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | teahupoo
# Processing Record 22 of Set 1 | troitsko-pechorsk
# Processing Record 23 of Set 1 | malakal
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | isetskoye
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | mokhsogollokh
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | altayskoye
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | dalvik
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | kadi
# Processing Record 41 of Set 1 | zyryanka
# Processing Record 42 of Set 1 | yuancheng
# Processing Record 43 of Set 1 | marienburg
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | huarmey
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | makakilo city
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | vardo
# Processing Record 4 of Set 2 | san policarpo
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | hit
# Processing Record 8 of Set 2 | dhidhdhoo
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | salinopolis
# Processing Record 11 of Set 2 | morondava
# Processing Record 12 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | venice
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | xinglongshan
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | coihaique
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | shar
# Processing Record 22 of Set 2 | aguas belas
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | grand-lahou
# Processing Record 25 of Set 2 | roald
# Processing Record 26 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 2 | port lincoln
# Processing Record 28 of Set 2 | fairhope
# Processing Record 29 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 2 | moranbah
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | pangody
# Processing Record 34 of Set 2 | kindu
# Processing Record 35 of Set 2 | tadine
# Processing Record 36 of Set 2 | russell
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | madimba
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | tulungagung
# Processing Record 41 of Set 2 | arlit
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | upington
# Processing Record 44 of Set 2 | nelson bay
# Processing Record 45 of Set 2 | reconquista
# Processing Record 46 of Set 2 | laurel
# Processing Record 47 of Set 2 | havre
# Processing Record 48 of Set 2 | rehoboth
# Processing Record 49 of Set 2 | sibolga
# Processing Record 50 of Set 2 | olafsvik
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | margate
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 3 | coahuayana
# Processing Record 7 of Set 3 | riyadh
# Processing Record 8 of Set 3 | oum hadjer
# Processing Record 9 of Set 3 | bonthe
# Processing Record 10 of Set 3 | sawakin
# Processing Record 11 of Set 3 | aboisso
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | neuquen
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | pahrump
# Processing Record 17 of Set 3 | gladstone
# Processing Record 18 of Set 3 | storm lake
# Processing Record 19 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 3 | havre-saint-pierre
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | springdale
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | vila do maio
# Processing Record 27 of Set 3 | lekoni
# Processing Record 28 of Set 3 | flinders
# Processing Record 29 of Set 3 | curup
# Processing Record 30 of Set 3 | gushikawa
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | davila
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | lazarev
# Processing Record 36 of Set 3 | los algarrobos
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | suarez
# Processing Record 42 of Set 3 | kenora
# Processing Record 43 of Set 3 | sabang
# Processing Record 44 of Set 3 | ahipara
# Processing Record 45 of Set 3 | otane
# Processing Record 46 of Set 3 | hauterive
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | kstovo
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | salcioara
# Processing Record 1 of Set 4 | jalu
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | lewistown
# Processing Record 4 of Set 4 | bethanien
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | orbetello
# Processing Record 7 of Set 4 | okha
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | matara
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | los llanos de aridane
# Processing Record 12 of Set 4 | baruun-urt
# Processing Record 13 of Set 4 | tiksi
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | nortelandia
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | dubbo
# Processing Record 18 of Set 4 | eydhafushi
# Processing Record 19 of Set 4 | carutapera
# Processing Record 20 of Set 4 | duluth
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | kloulklubed
# Processing Record 23 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 4 | ghanzi
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | tuatapere
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | brae
# Processing Record 29 of Set 4 | ust-nera
# Processing Record 30 of Set 4 | shakawe
# Processing Record 31 of Set 4 | natal
# Processing Record 32 of Set 4 | noumea
# Processing Record 33 of Set 4 | goderich
# Processing Record 34 of Set 4 | terrak
# Processing Record 35 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 4 | sitka
# Processing Record 37 of Set 4 | yairipok
# Processing Record 38 of Set 4 | thinadhoo
# Processing Record 39 of Set 4 | rincon
# Processing Record 40 of Set 4 | grafton
# Processing Record 41 of Set 4 | valday
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | beroroha
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | znamenka
# Processing Record 47 of Set 4 | mago
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | gedo
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | abu kamal
# Processing Record 3 of Set 5 | dzilam gonzalez
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | lavrentiya
# Processing Record 6 of Set 5 | porto torres
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 5 | zhigalovo
# Processing Record 11 of Set 5 | rawson
# Processing Record 12 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 5 | loa janan
# Processing Record 14 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 5 | rabupura
# Processing Record 16 of Set 5 | jinchang
# Processing Record 17 of Set 5 | shambu
# Processing Record 18 of Set 5 | santa rosa
# Processing Record 19 of Set 5 | dicabisagan
# Processing Record 20 of Set 5 | saint george
# Processing Record 21 of Set 5 | acarau
# Processing Record 22 of Set 5 | korla
# Processing Record 23 of Set 5 | kununurra
# Processing Record 24 of Set 5 | san angelo
# Processing Record 25 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 5 | el angel
# Processing Record 27 of Set 5 | muyinga
# Processing Record 28 of Set 5 | bend
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | redmond
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | betanzos
# Processing Record 33 of Set 5 | marawi
# Processing Record 34 of Set 5 | honningsvag
# Processing Record 35 of Set 5 | pingshan
# Processing Record 36 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 5 | ahuimanu
# Processing Record 39 of Set 5 | gazli
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 5 | newtownards
# Processing Record 43 of Set 5 | fortuna
# Processing Record 44 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | tual
# Processing Record 47 of Set 5 | andenes
# Processing Record 48 of Set 5 | tiznit
# Processing Record 49 of Set 5 | lagoa
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | general bravo
# Processing Record 2 of Set 6 | seinajoki
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | buraydah
# Processing Record 5 of Set 6 | nhulunbuy
# Processing Record 6 of Set 6 | kutum
# Processing Record 7 of Set 6 | laguna
# Processing Record 8 of Set 6 | ancud
# Processing Record 9 of Set 6 | qaanaaq
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | shizunai
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | suao
# City not found. Skipping...
# Processing Record 14 of Set 6 | calais
# Processing Record 15 of Set 6 | magadan
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | danielskuil
# Processing Record 19 of Set 6 | manadhoo
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | karpathos
# Processing Record 22 of Set 6 | victor harbor
# Processing Record 23 of Set 6 | leshukonskoye
# Processing Record 24 of Set 6 | teya
# Processing Record 25 of Set 6 | buchanan
# Processing Record 26 of Set 6 | kitakata
# Processing Record 27 of Set 6 | cherskiy
# Processing Record 28 of Set 6 | komsomolskiy
# Processing Record 29 of Set 6 | abdanan
# Processing Record 30 of Set 6 | belis
# Processing Record 31 of Set 6 | nedjo
# Processing Record 32 of Set 6 | shingu
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | hayrabolu
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | kawalu
# Processing Record 37 of Set 6 | mendoza
# Processing Record 38 of Set 6 | zhanaozen
# Processing Record 39 of Set 6 | vestmannaeyjar
# Processing Record 40 of Set 6 | urzhum
# Processing Record 41 of Set 6 | costinesti
# Processing Record 42 of Set 6 | fairbanks
# Processing Record 43 of Set 6 | orocue
# Processing Record 44 of Set 6 | tengushevo
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | oneonta
# Processing Record 47 of Set 6 | hobyo
# Processing Record 48 of Set 6 | suntar
# Processing Record 49 of Set 6 | vila velha
# Processing Record 50 of Set 6 | mandan
# Processing Record 1 of Set 7 | cusuna
# Processing Record 2 of Set 7 | tromso
# Processing Record 3 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 4 of Set 7 | omboue
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | bolotnoye
# Processing Record 7 of Set 7 | san jeronimo
# Processing Record 8 of Set 7 | alexandria
# Processing Record 9 of Set 7 | cabo san lucas
# Processing Record 10 of Set 7 | souillac
# Processing Record 11 of Set 7 | sorland
# Processing Record 12 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 7 | iskateley
# Processing Record 15 of Set 7 | svetlyy
# Processing Record 16 of Set 7 | bereda
# Processing Record 17 of Set 7 | gat
# Processing Record 18 of Set 7 | simao
# Processing Record 19 of Set 7 | tucupita
# Processing Record 20 of Set 7 | lata
# Processing Record 21 of Set 7 | tuktoyaktuk
# Processing Record 22 of Set 7 | sungaipenuh
# Processing Record 23 of Set 7 | moerai
# Processing Record 24 of Set 7 | san luis
# Processing Record 25 of Set 7 | kushima
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | priargunsk
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | sereflikochisar
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | hambantota
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | labytnangi
# Processing Record 36 of Set 7 | comodoro rivadavia
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | fernley
# Processing Record 39 of Set 7 | sitangkai
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | ussel
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | chinique
# Processing Record 44 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 7 | balkanabat
# Processing Record 46 of Set 7 | castro
# Processing Record 47 of Set 7 | chimbote
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | kushmurun
# Processing Record 50 of Set 7 | ippy
# Processing Record 1 of Set 8 | bichura
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 4 of Set 8 | sumkino
# Processing Record 5 of Set 8 | lundazi
# Processing Record 6 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | jiwani
# Processing Record 9 of Set 8 | dehloran
# Processing Record 10 of Set 8 | baghdad
# Processing Record 11 of Set 8 | panguna
# Processing Record 12 of Set 8 | arraial do cabo
# Processing Record 13 of Set 8 | harper
# Processing Record 14 of Set 8 | andros town
# Processing Record 15 of Set 8 | oranjemund
# Processing Record 16 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 8 | maua
# Processing Record 18 of Set 8 | ligayan
# Processing Record 19 of Set 8 | parabel
# Processing Record 20 of Set 8 | alekseyevskoye
# Processing Record 21 of Set 8 | bahia blanca
# Processing Record 22 of Set 8 | saint anthony
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | barranca
# Processing Record 25 of Set 8 | havelock
# Processing Record 26 of Set 8 | tabuk
# Processing Record 27 of Set 8 | kraskino
# Processing Record 28 of Set 8 | ormara
# Processing Record 29 of Set 8 | krasnoselkup
# Processing Record 30 of Set 8 | hami
# Processing Record 31 of Set 8 | richards bay
# Processing Record 32 of Set 8 | miguel calmon
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | hervey bay
# Processing Record 35 of Set 8 | hofn
# Processing Record 36 of Set 8 | alofi
# Processing Record 37 of Set 8 | beidao
# Processing Record 38 of Set 8 | omaruru
# Processing Record 39 of Set 8 | turayf
# Processing Record 40 of Set 8 | roma
# Processing Record 41 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 8 | novo aripuana
# Processing Record 43 of Set 8 | charters towers
# Processing Record 44 of Set 8 | tarakan
# Processing Record 45 of Set 8 | nioro
# Processing Record 46 of Set 8 | port augusta
# Processing Record 47 of Set 8 | fenoarivo
# Processing Record 48 of Set 8 | mayo
# Processing Record 49 of Set 8 | manado
# Processing Record 50 of Set 8 | abu samrah
# Processing Record 1 of Set 9 | wiarton
# Processing Record 2 of Set 9 | dapitan
# Processing Record 3 of Set 9 | darnah
# Processing Record 4 of Set 9 | kainantu
# Processing Record 5 of Set 9 | westerkappeln
# Processing Record 6 of Set 9 | barcelos
# Processing Record 7 of Set 9 | port macquarie
# Processing Record 8 of Set 9 | katrineholm
# Processing Record 9 of Set 9 | taree
# Processing Record 10 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 9 | geraldton
# Processing Record 12 of Set 9 | san quintin
# Processing Record 13 of Set 9 | den helder
# Processing Record 14 of Set 9 | moultrie
# Processing Record 15 of Set 9 | anito
# Processing Record 16 of Set 9 | lyubashivka
# Processing Record 17 of Set 9 | srednekolymsk
# Processing Record 18 of Set 9 | hualmay
# Processing Record 19 of Set 9 | duz
# City not found. Skipping...
# Processing Record 20 of Set 9 | doha
# Processing Record 21 of Set 9 | ayagoz
# Processing Record 22 of Set 9 | chokurdakh
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | north bend
# Processing Record 25 of Set 9 | vao
# Processing Record 26 of Set 9 | rio gallegos
# Processing Record 27 of Set 9 | huadian
# Processing Record 28 of Set 9 | nome
# Processing Record 29 of Set 9 | verkhnetulomskiy
# Processing Record 30 of Set 9 | voi
# Processing Record 31 of Set 9 | kilindoni
# Processing Record 32 of Set 9 | zharkent
# Processing Record 33 of Set 9 | talavera de la reina
# Processing Record 34 of Set 9 | chapais
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | bam
# Processing Record 37 of Set 9 | andrews
# Processing Record 38 of Set 9 | acapulco
# Processing Record 39 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 9 | kungurtug
# Processing Record 41 of Set 9 | norman wells
# Processing Record 42 of Set 9 | hoa binh
# Processing Record 43 of Set 9 | ilhabela
# Processing Record 44 of Set 9 | azoyu
# Processing Record 45 of Set 9 | inuvik
# Processing Record 46 of Set 9 | son la
# Processing Record 47 of Set 9 | rosarito
# Processing Record 48 of Set 9 | nong phai
# Processing Record 49 of Set 9 | huaicheng
# Processing Record 50 of Set 9 | kharp
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | parana
# Processing Record 3 of Set 10 | wasilla
# Processing Record 4 of Set 10 | meadow lake
# Processing Record 5 of Set 10 | cam ranh
# Processing Record 6 of Set 10 | asau
# Processing Record 7 of Set 10 | kristiinankaupunki
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | bredy
# Processing Record 10 of Set 10 | vila franca do campo
# Processing Record 11 of Set 10 | mecca
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | natchez
# Processing Record 15 of Set 10 | eureka
# Processing Record 16 of Set 10 | ugoofaaru
# Processing Record 17 of Set 10 | tsaratanana
# Processing Record 18 of Set 10 | atar
# Processing Record 19 of Set 10 | gold coast
# Processing Record 20 of Set 10 | saldanha
# Processing Record 21 of Set 10 | hays
# Processing Record 22 of Set 10 | okhotsk
# Processing Record 23 of Set 10 | qaqortoq
# Processing Record 24 of Set 10 | bandarbeyla
# Processing Record 25 of Set 10 | tobermory
# Processing Record 26 of Set 10 | el tarra
# Processing Record 27 of Set 10 | uige
# Processing Record 28 of Set 10 | kailua
# Processing Record 29 of Set 10 | neiafu
# Processing Record 30 of Set 10 | axim
# Processing Record 31 of Set 10 | bilibino
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | mareeba
# Processing Record 34 of Set 10 | karachi
# Processing Record 35 of Set 10 | juneau
# Processing Record 36 of Set 10 | marzuq
# Processing Record 37 of Set 10 | russkaya polyana
# Processing Record 38 of Set 10 | copalillo
# Processing Record 39 of Set 10 | sangar
# Processing Record 40 of Set 10 | qom
# Processing Record 41 of Set 10 | sesheke
# Processing Record 42 of Set 10 | darhan
# Processing Record 43 of Set 10 | oyama
# Processing Record 44 of Set 10 | twentynine palms
# Processing Record 45 of Set 10 | awjilah
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 10 | saint-georges
# Processing Record 49 of Set 10 | nanakuli
# Processing Record 50 of Set 10 | sartana
# Processing Record 1 of Set 11 | ketchikan
# Processing Record 2 of Set 11 | lamu
# Processing Record 3 of Set 11 | guanambi
# Processing Record 4 of Set 11 | karratha
# Processing Record 5 of Set 11 | suchitlan
# Processing Record 6 of Set 11 | fairview
# Processing Record 7 of Set 11 | zhigansk
# Processing Record 8 of Set 11 | maragogi
# Processing Record 9 of Set 11 | yinchuan
# Processing Record 10 of Set 11 | inzer
# Processing Record 11 of Set 11 | capreol
# Processing Record 12 of Set 11 | shirhatti
# Processing Record 13 of Set 11 | plettenberg bay
# Processing Record 14 of Set 11 | el sauce
# Processing Record 15 of Set 11 | zemio
# Processing Record 16 of Set 11 | kieta
# Processing Record 17 of Set 11 | awbari
# Processing Record 18 of Set 11 | grants
# Processing Record 19 of Set 11 | portland
# Processing Record 20 of Set 11 | alappuzha
# Processing Record 21 of Set 11 | raudeberg
# Processing Record 22 of Set 11 | bada
# Processing Record 23 of Set 11 | henties bay
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | gornozavodsk
# Processing Record 26 of Set 11 | piranshahr
# Processing Record 27 of Set 11 | eyl
# Processing Record 28 of Set 11 | ferkessedougou
# Processing Record 29 of Set 11 | marsabit
# Processing Record 30 of Set 11 | nishihara
# Processing Record 31 of Set 11 | soest
# Processing Record 32 of Set 11 | adrar
# Processing Record 33 of Set 11 | yumen
# Processing Record 34 of Set 11 | madera
# Processing Record 35 of Set 11 | mitsamiouli
# Processing Record 36 of Set 11 | balkhash
# Processing Record 37 of Set 11 | necochea
# Processing Record 38 of Set 11 | tamano
# Processing Record 39 of Set 11 | tianpeng
# Processing Record 40 of Set 11 | valparaiso
# Processing Record 41 of Set 11 | broome
# Processing Record 42 of Set 11 | nuuk
# Processing Record 43 of Set 11 | moussoro
# Processing Record 44 of Set 11 | salalah
# Processing Record 45 of Set 11 | singaraja
# Processing Record 46 of Set 11 | santa maria
# Processing Record 47 of Set 11 | taltal
# Processing Record 48 of Set 11 | cap malheureux
# Processing Record 49 of Set 11 | govindgarh
# Processing Record 50 of Set 11 | yar-sale
# Processing Record 1 of Set 12 | sompeta
# Processing Record 2 of Set 12 | logan
# Processing Record 3 of Set 12 | elizabethtown
# Processing Record 4 of Set 12 | ulladulla
# Processing Record 5 of Set 12 | atasu
# Processing Record 6 of Set 12 | mananjary
# Processing Record 7 of Set 12 | viedma
# Processing Record 8 of Set 12 | kysyl-syr
# Processing Record 9 of Set 12 | drayton valley
# Processing Record 10 of Set 12 | fayaoue
# Processing Record 11 of Set 12 | ulaanbaatar
# Processing Record 12 of Set 12 | qandala
# Processing Record 13 of Set 12 | carhuamayo
# Processing Record 14 of Set 12 | carauari
# Processing Record 15 of Set 12 | cabatuan
# Processing Record 16 of Set 12 | mtsamboro
# Processing Record 17 of Set 12 | usinsk
# Processing Record 18 of Set 12 | gulbarga
# Processing Record 19 of Set 12 | rio grande
# Processing Record 20 of Set 12 | mehamn
# Processing Record 21 of Set 12 | angoche
# Processing Record 22 of Set 12 | buenaventura
# Processing Record 23 of Set 12 | longhua
# Processing Record 24 of Set 12 | brumunddal
# Processing Record 25 of Set 12 | wanning
# Processing Record 26 of Set 12 | nyurba
# Processing Record 27 of Set 12 | dosso
# Processing Record 28 of Set 12 | tyukalinsk
# Processing Record 29 of Set 12 | beihai
# Processing Record 30 of Set 12 | salinas
# Processing Record 31 of Set 12 | kirkwood
# Processing Record 32 of Set 12 | phan thiet
# Processing Record 33 of Set 12 | terneuzen
# Processing Record 34 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 12 | san vicente
# Processing Record 36 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 12 | gambela
# Processing Record 38 of Set 12 | tourlaville
# Processing Record 39 of Set 12 | kousseri
# Processing Record 40 of Set 12 | lincoln
# Processing Record 41 of Set 12 | vedaranniyam
# City not found. Skipping...
# Processing Record 42 of Set 12 | namatanai
# Processing Record 43 of Set 12 | bozoum
# Processing Record 44 of Set 12 | egvekinot
# Processing Record 45 of Set 12 | qostanay
# Processing Record 46 of Set 12 | mwense
# Processing Record 47 of Set 12 | brokopondo
# Processing Record 48 of Set 12 | banda aceh
# Processing Record 49 of Set 12 | peniche
# Processing Record 50 of Set 12 | tynda
# Processing Record 1 of Set 13 | te anau
# Processing Record 2 of Set 13 | asfi
# Processing Record 3 of Set 13 | smidovich
# Processing Record 4 of Set 13 | iquitos
# Processing Record 5 of Set 13 | mogadishu
# Processing Record 6 of Set 13 | abu zabad
# Processing Record 7 of Set 13 | tommot
# Processing Record 8 of Set 13 | tarancon
# Processing Record 9 of Set 13 | alasehir
# Processing Record 10 of Set 13 | ust-ilimsk
# Processing Record 11 of Set 13 | gornopravdinsk
# Processing Record 12 of Set 13 | progreso
# Processing Record 13 of Set 13 | tebingtinggi
# Processing Record 14 of Set 13 | bhimunipatnam
# Processing Record 15 of Set 13 | plerin
# Processing Record 16 of Set 13 | bodaybo
# Processing Record 17 of Set 13 | guerrero negro
# Processing Record 18 of Set 13 | ambilobe
# Processing Record 19 of Set 13 | milkovo
# Processing Record 20 of Set 13 | atambua
# Processing Record 21 of Set 13 | ternate
# Processing Record 22 of Set 13 | mosetse
# Processing Record 23 of Set 13 | oriximina
# Processing Record 24 of Set 13 | kupang
# Processing Record 25 of Set 13 | kletnya
# Processing Record 26 of Set 13 | yerbogachen
# Processing Record 27 of Set 13 | kiruna
# Processing Record 28 of Set 13 | seymchan
# Processing Record 29 of Set 13 | dera bugti
# Processing Record 30 of Set 13 | kenai
# Processing Record 31 of Set 13 | lanzhou
# Processing Record 32 of Set 13 | pipar
# Processing Record 33 of Set 13 | obo
# Processing Record 34 of Set 13 | hibbing
# Processing Record 35 of Set 13 | puerto leguizamo
# Processing Record 36 of Set 13 | batemans bay
# Processing Record 37 of Set 13 | general roca
# Processing Record 38 of Set 13 | lambakin
# Processing Record 39 of Set 13 | kuala selangor
# Processing Record 40 of Set 13 | port hardy
# Processing Record 41 of Set 13 | dudinka
# Processing Record 42 of Set 13 | corrente
# Processing Record 43 of Set 13 | jalingo
# Processing Record 44 of Set 13 | safaga
# Processing Record 45 of Set 13 | puerto madryn
# Processing Record 46 of Set 13 | kavaratti
# Processing Record 47 of Set 13 | kamaishi
# Processing Record 48 of Set 13 | assiniboia
# Processing Record 49 of Set 13 | boshnyakovo
# Processing Record 50 of Set 13 | castelnaudary
# Processing Record 1 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 14 | kaeo
# Processing Record 3 of Set 14 | oktyabrskoye
# Processing Record 4 of Set 14 | kemijarvi
# Processing Record 5 of Set 14 | alice springs
# Processing Record 6 of Set 14 | phnum penh
# City not found. Skipping...
# Processing Record 7 of Set 14 | mapiripan
# Processing Record 8 of Set 14 | manica
# Processing Record 9 of Set 14 | tarko-sale
# Processing Record 10 of Set 14 | porto novo
# Processing Record 11 of Set 14 | bar harbor
# Processing Record 12 of Set 14 | chepareria
# Processing Record 13 of Set 14 | gari
# Processing Record 14 of Set 14 | maniitsoq
# Processing Record 15 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 16 of Set 14 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 17 of Set 14 | udachnyy
# Processing Record 18 of Set 14 | yeppoon
# Processing Record 19 of Set 14 | pimentel
# Processing Record 20 of Set 14 | tilichiki
# Processing Record 21 of Set 14 | porosozero
# Processing Record 22 of Set 14 | ucluelet
# Processing Record 23 of Set 14 | vallenar
# Processing Record 24 of Set 14 | bijapur
# Processing Record 25 of Set 14 | kankaanpaa
# Processing Record 26 of Set 14 | altea
# Processing Record 27 of Set 14 | umm kaddadah
# Processing Record 28 of Set 14 | bafq
# Processing Record 29 of Set 14 | aranos
# Processing Record 30 of Set 14 | lahaina
# Processing Record 31 of Set 14 | byron bay
# Processing Record 32 of Set 14 | lichtenburg
# Processing Record 33 of Set 14 | sola
# Processing Record 34 of Set 14 | gigmoto
# Processing Record 35 of Set 14 | mount gambier
# Processing Record 36 of Set 14 | vanavara
# Processing Record 37 of Set 14 | trincomalee
# Processing Record 38 of Set 14 | morgantown
# Processing Record 39 of Set 14 | bartlesville
# Processing Record 40 of Set 14 | vysokogornyy
# Processing Record 41 of Set 14 | aksarka
# Processing Record 42 of Set 14 | coruripe
# Processing Record 43 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 14 | nanortalik
# Processing Record 45 of Set 14 | kilis
# Processing Record 46 of Set 14 | beringovskiy
# Processing Record 47 of Set 14 | la crosse
# Processing Record 48 of Set 14 | lieksa
# Processing Record 49 of Set 14 | shirdi
# Processing Record 50 of Set 14 | atherton
# Processing Record 1 of Set 15 | mazatlan
# Processing Record 2 of Set 15 | ryotsu
# Processing Record 3 of Set 15 | mayumba
# Processing Record 4 of Set 15 | amurzet
# Processing Record 5 of Set 15 | sao gotardo
# Processing Record 6 of Set 15 | tangwani
# Processing Record 7 of Set 15 | santiago del estero
# Processing Record 8 of Set 15 | valera
# Processing Record 9 of Set 15 | bad frankenhausen
# Processing Record 10 of Set 15 | butajira
# Processing Record 11 of Set 15 | agara
# Processing Record 12 of Set 15 | calahorra
# Processing Record 13 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 15 | prainha
# Processing Record 15 of Set 15 | lososina
# Processing Record 16 of Set 15 | nalut
# Processing Record 17 of Set 15 | sur
# Processing Record 18 of Set 15 | soyo
# Processing Record 19 of Set 15 | college
# Processing Record 20 of Set 15 | lorengau
# Processing Record 21 of Set 15 | la asuncion
# Processing Record 22 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 15 | basco
# Processing Record 24 of Set 15 | skelleftea
# Processing Record 25 of Set 15 | mutuipe
# Processing Record 26 of Set 15 | gull lake
# Processing Record 27 of Set 15 | prince rupert
# Processing Record 28 of Set 15 | vaovai
# City not found. Skipping...
# Processing Record 29 of Set 15 | rognan
# Processing Record 30 of Set 15 | morehead
# Processing Record 31 of Set 15 | fort portal
# Processing Record 32 of Set 15 | ghamarwin
# City not found. Skipping...
# Processing Record 33 of Set 15 | xinzhi
# Processing Record 34 of Set 15 | antiguo morelos
# Processing Record 35 of Set 15 | shwebo
# Processing Record 36 of Set 15 | sao borja
# Processing Record 37 of Set 15 | nouakchott
# Processing Record 38 of Set 15 | yenagoa
# Processing Record 39 of Set 15 | canakkale
# Processing Record 40 of Set 15 | barrancas
# Processing Record 41 of Set 15 | namibe
# Processing Record 42 of Set 15 | iraquara
# Processing Record 43 of Set 15 | kapit
# Processing Record 44 of Set 15 | dauriya
# Processing Record 45 of Set 15 | navlya
# Processing Record 46 of Set 15 | palana
# Processing Record 47 of Set 15 | berlevag
# Processing Record 48 of Set 15 | bamboo
# Processing Record 49 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 50 of Set 15 | yuma
# Processing Record 1 of Set 16 | kalmunai
# Processing Record 2 of Set 16 | novoagansk
# Processing Record 3 of Set 16 | kaabong
# Processing Record 4 of Set 16 | omsukchan
# Processing Record 5 of Set 16 | takoradi
# Processing Record 6 of Set 16 | port alberni
# Processing Record 7 of Set 16 | aden
# Processing Record 8 of Set 16 | luba
# Processing Record 9 of Set 16 | normandin
# Processing Record 10 of Set 16 | ardistan
# City not found. Skipping...
# Processing Record 11 of Set 16 | bugko
# Processing Record 12 of Set 16 | moose factory
# Processing Record 13 of Set 16 | dingle
# Processing Record 14 of Set 16 | kashary
# Processing Record 15 of Set 16 | pangai
# Processing Record 16 of Set 16 | chicama
# Processing Record 17 of Set 16 | machhlishahr
# Processing Record 18 of Set 16 | constitucion
# Processing Record 19 of Set 16 | kadiri
# Processing Record 20 of Set 16 | alotau
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     58.26        70         100
# 1         Mataura -46.1927  168.8643     45.48        65           4
# 2        Tasiilaq  65.6145  -37.6368     35.76        80          44
# 3            Kula  38.5473   28.6498     61.32        50           0
# 4           Avera  33.1940  -82.5271     80.65        67          99
# 5          Bethel  41.3712  -73.4140     77.68        90           0
# 6           Bluff -46.6000  168.3333     45.81        69           2
# 7  Saint-Philippe -21.3585   55.7679     64.22        84          42
# 8          Dikson  73.5069   80.5464     51.66        80          94
# 9         Ushuaia -54.8000  -68.3000     35.26        87          75
#
#    Wind Speed Weather Description Country                 Date
# 0        3.00     overcast clouds      AU  2022-07-23 02:35:32
# 1        2.84           clear sky      NZ  2022-07-23 02:40:21
# 2        7.45    scattered clouds      GL  2022-07-23 02:35:46
# 3        4.94           clear sky      TR  2022-07-23 02:40:22
# 4        5.57     overcast clouds      US  2022-07-23 02:40:22
# 5        0.00           clear sky      US  2022-07-23 02:35:30
# 6        3.20           clear sky      NZ  2022-07-23 02:40:23
# 7       14.52          light rain      RE  2022-07-23 02:40:23
# 8       12.86     overcast clouds      RU  2022-07-23 02:40:24
# 9       25.32       broken clouds      AR  2022-07-23 02:40:24

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
